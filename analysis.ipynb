# %%
import camelot
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
koridor_data = {}

for i in range(1, 15):
    filename = f"Jumlah Pelanggan BRT Transjakarta Perhalte Koridor {i} Tahun 2024.pdf"
    try:
        tables = camelot.read_pdf(filename, pages="all")
        df = tables[0].df
        df = df.drop(df.columns[0], axis=1)
        df.columns = df.iloc[1]
        df = df.iloc[2:].reset_index(drop=True)
        df = df[df[df.columns[0]].str.strip().astype(bool)]  # Remove empty rows
        for col in df.columns[1:]:
            df[col] = pd.to_numeric(df[col].str.replace('.', ''), errors='coerce')
        koridor_data[f"Koridor{i}"] = df
        print(f"✓ Loaded Koridor {i}: {len(df)} stops")
    except Exception as e:
        print(f"✗ Failed to load Koridor {i}: {e}")

print(f"✓ Total loaded corridors: {len(koridor_data)}")
# Out:
# ✓ Loaded Koridor 1: 30 stops
# ✓ Loaded Koridor 2: 24 stops
# ✓ Loaded Koridor 3: 13 stops
# ✓ Loaded Koridor 4: 17 stops
# ✓ Loaded Koridor 5: 17 stops
# ✓ Loaded Koridor 6: 18 stops
# ✓ Loaded Koridor 7: 14 stops
# ✓ Loaded Koridor 8: 22 stops
# ✓ Loaded Koridor 9: 33 stops
# ✓ Loaded Koridor 10: 18 stops
# ✓ Loaded Koridor 11: 15 stops
# ✓ Loaded Koridor 12: 14 stops
# ✓ Loaded Koridor 13: 15 stops
# ✓ Loaded Koridor 14: 5 stops
# ✓ Total loaded corridors: 14

# %%
# ==================== CORRIDOR SPECIFICATIONS ====================
corridor_specs = {
    1: {'length_km': 12.9, 'stations': 30},
    2: {'length_km': 14.0, 'stations': 24},
    3: {'length_km': 19.0, 'stations': 13},
    4: {'length_km': 11.85, 'stations': 17},
    5: {'length_km': 13.5, 'stations': 17},
    6: {'length_km': 13.3, 'stations': 18},
    7: {'length_km': 12.8, 'stations': 14},
    8: {'length_km': 26.0, 'stations': 22},
    9: {'length_km': 28.8, 'stations': 33},
    10: {'length_km': 19.4, 'stations': 18},
    11: {'length_km': 11.4, 'stations': 15},
    12: {'length_km': 23.8, 'stations': 14},
    13: {'length_km': 9.4, 'stations': 15},
    14: {'length_km': 9.7, 'stations': 5}
}

# %%
# ==================== OPTIMIZATION CLASS ====================
class TransjakartaSystemOptimizer:
    def __init__(self, koridor_data, corridor_specs):
        self.koridor_data = koridor_data
        self.corridor_specs = corridor_specs
        self.results = {}
        
    def process_corridor_data(self, corridor_name):
        """Process passenger data for a specific corridor"""
        if corridor_name not in self.koridor_data:
            return None
            
        df = self.koridor_data[corridor_name].copy()
        month_cols = [col for col in df.columns if col != df.columns[0]]
        
        df['Avg_Monthly'] = df[month_cols].mean(axis=1)
        df['Peak_Month'] = df[month_cols].max(axis=1)
        df['Daily_Avg'] = df['Avg_Monthly'] / 30
        df['Peak_Hour'] = df['Daily_Avg'] * 0.15
        
        return df.dropna(subset=['Avg_Monthly']).reset_index(drop=True)
    
    def calculate_cycle_time(self, corridor_num, avg_speed=25, dwell_time=0.5, layover=10):
        """Calculate round trip cycle time"""
        specs = self.corridor_specs[corridor_num]
        length = specs['length_km']
        travel_time = (length * 2 * 60) / avg_speed
        total_dwell = dwell_time * specs['stations'] * 2
        return travel_time + total_dwell + layover
    
    
    def optimize_corridor(self, corridor_num, vehicle_capacity=103, load_factor=0.85):
        """Optimize fleet for specific corridor"""
        corridor_name = f"Koridor{corridor_num}"
        df = self.process_corridor_data(corridor_name)
        
        if df is None:
            return None
            
        # Calculate demand
        total_monthly = df['Avg_Monthly'].sum()
        peak_demand = df['Peak_Hour'].sum()
        
        # Get specs and cycle time
        specs = self.corridor_specs[corridor_num]
        cycle_time = self.calculate_cycle_time(corridor_num)
        
        # Optimization scenarios
        effective_capacity = vehicle_capacity * load_factor
        min_headway = max((effective_capacity * 60) / peak_demand, 3) if peak_demand > 0 else 10
        
        scenarios = {
            'Current': 10,
            'Optimal': min_headway,
            'Balanced': max(7, min_headway * 0.7),
            'Frequent': 5,
            'Cost_Efficient': 12
        }
        
        scenario_results = {}
        for name, headway in scenarios.items():
            fleet_size = np.ceil(cycle_time / headway) 
            total_fleet = fleet_size * 1.2 # For operational provisions
            
            buses_per_hour = 60 / headway
            hourly_capacity = buses_per_hour * effective_capacity
            utilization = (peak_demand / hourly_capacity * 100) if hourly_capacity > 0 else 0
            
            # Cost calculation
            fuel_per_bus_day = (specs['length_km'] * 2 * 8) / 3.5  #8 trips, 3.5km/L
            fuel_cost = total_fleet * fuel_per_bus_day * 6800  #IDR 6.8k/L (BioSolar)
            driver_cost = total_fleet * 550000  # 1 driver + 1 guide @ IDR 16.5 Million/month each
            maintenance_cost = total_fleet * 530000 #530k IDR average/day
            daily_cost = fuel_cost + driver_cost + maintenance_cost
            
            scenario_results[name] = {
                'headway': headway,
                'fleet_size': fleet_size,
                'total_fleet': total_fleet,
                'utilization': utilization,
                'daily_cost': daily_cost,
                'hourly_capacity': hourly_capacity,
                'fuel_liters': total_fleet * fuel_per_bus_day
            }
        
        return {
            'corridor': corridor_num,
            'specs': specs,
            'demand': {
                'monthly_total': total_monthly,
                'daily_total': total_monthly / 30,
                'peak_hour': peak_demand,
                'active_stops': len(df)
            },
            'scenarios': scenario_results,
            'passenger_data': df,
            'cycle_time': cycle_time
        }
    
    def analyze_hotspots(self, corridor_num, top_n=10):
        """Identify passenger hotspots"""
        corridor_name = f"Koridor{corridor_num}"
        df = self.process_corridor_data(corridor_name)
        
        if df is None:
            return []
            
        return df.nlargest(top_n, 'Avg_Monthly')[
            [df.columns[0], 'Avg_Monthly', 'Daily_Avg', 'Peak_Hour']
        ].to_dict('records')
    
    def recommend_new_stops(self, corridor_num, top_n=5):
        """Recommend new bus stop locations"""
        corridor_name = f"Koridor{corridor_num}"
        df = self.process_corridor_data(corridor_name)
        
        if df is None or len(df) < 2:
            return []
            
        recommendations = []
        for i in range(len(df) - 1):
            current = df.iloc[i]
            next_stop = df.iloc[i + 1]
            
            potential_demand = (current['Avg_Monthly'] + next_stop['Avg_Monthly']) * 0.3
            
            recommendations.append({
                'location': f"Between {current[df.columns[0]]} - {next_stop[df.columns[0]]}",
                'potential_monthly': potential_demand,
                'priority_score': potential_demand,
                'current_stop': current[df.columns[0]],
                'next_stop': next_stop[df.columns[0]]
            })
        
        recommendations.sort(key=lambda x: x['potential_monthly'], reverse=True)
        return recommendations[:top_n]
    
    def analyze_all_corridors(self):
        """Analyze all loaded corridors"""
        all_results = {}
        summary_data = []
        
        for corridor_name in self.koridor_data.keys():
            corridor_num = int(corridor_name.replace('Koridor', ''))
            result = self.optimize_corridor(corridor_num)
            
            if result:
                all_results[corridor_num] = result
                balanced = result['scenarios']['Balanced']
                
                summary_data.append({
                    'Corridor': corridor_num,
                    'Length_km': result['specs']['length_km'],
                    'Active_Stops': result['demand']['active_stops'],
                    'Monthly_Passengers': result['demand']['monthly_total'],
                    'Peak_Hour_Demand': result['demand']['peak_hour'],
                    'Recommended_Fleet': balanced['total_fleet'],
                    'Recommended_Headway': balanced['headway'],
                    'Daily_Cost_IDR': balanced['daily_cost'],
                    'Utilization_pct': balanced['utilization'],
                    'Daily_Fuel_L': balanced['fuel_liters']
                })
        
        return all_results, pd.DataFrame(summary_data) if summary_data else None

    def print_corridor_analysis(self, corridor_num):
        """Print detailed analysis for a specific corridor"""
        print(f"\n{'='*20} KORIDOR {corridor_num} ANALYSIS {'='*20}")
        
        result = self.optimize_corridor(corridor_num)
        if result is None:
            print(f"No data available for Koridor {corridor_num}")
            return
            
        # Basic info
        print(f"Corridor Length: {result['specs']['length_km']} km")
        print(f"Active Stops: {result['demand']['active_stops']}")
        print(f"Monthly Passengers: {result['demand']['monthly_total']:,.0f}")
        print(f"Peak Hour Demand: {result['demand']['peak_hour']:,.0f} passengers/hour")
        
        # Scenario comparison
        print(f"\nSCENARIO COMPARISON:")
        print(f"{'Scenario':<15} {'Headway':<8} {'Fleet':<6} {'Util%':<8} {'Daily Cost':<12}")
        print("-" * 60)
        
        recommended_scenario = None
        best_score = 0
        
        for scenario, data in result['scenarios'].items():
            utilization = data['utilization']
            cost_millions = data['daily_cost'] / 1000000
            
            print(f"{scenario:<15} {data['headway']:<8.1f} {data['total_fleet']:<6.0f} "
                  f"{utilization:<8.1f} IDR {cost_millions:<8.1f}M")
            
            # Find best scenario (reasonable utilization + cost efficiency)
            if 60 <= utilization <= 150:
                efficiency_score = 100 - abs(utilization - 100)
                cost_score = max(0, 100 - cost_millions * 5)
                total_score = efficiency_score + cost_score
                
                if total_score > best_score:
                    best_score = total_score
                    recommended_scenario = scenario
        
        # Recommendations
        if recommended_scenario:
            rec_data = result['scenarios'][recommended_scenario]
            print(f"\nRECOMMENDED SCENARIO: {recommended_scenario}")
            print(f"   Fleet Size: {rec_data['total_fleet']:.0f} buses")
            print(f"   Headway: {rec_data['headway']:.0f} minutes")
            print(f"   Utilization: {rec_data['utilization']:.1f}%")
            print(f"   Daily Cost: IDR {rec_data['daily_cost']/1000000:.1f} million")
            print(f"   Daily Fuel: {rec_data['fuel_liters']:.0f} liters")
        
        # Hotspots
        hotspots = self.analyze_hotspots(corridor_num, 5)
        if hotspots:
            print(f"\nTOP 5 PASSENGER HOTSPOTS:")
            for i, stop in enumerate(hotspots, 1):
                print(f"   {i}. {stop[result['passenger_data'].columns[0]]}: {stop['Avg_Monthly']:,.0f}/month")
        
        # New stop recommendations
        new_stops = self.recommend_new_stops(corridor_num, 3)
        if new_stops:
            print(f"\nTOP 3 NEW STOP RECOMMENDATIONS:")
            for i, rec in enumerate(new_stops, 1):
                print(f"   {i}. {rec['location']}")
                print(f"      Potential: {rec['potential_monthly']:,.0f} passengers/month")

# ==================== ANALYSIS EXECUTION ====================
# Initialize optimizer
optimizer = TransjakartaSystemOptimizer(koridor_data, corridor_specs)

# Analyze all corridors
print("\nAnalyzing all loaded corridors...")
all_results, summary_df = optimizer.analyze_all_corridors()

if summary_df is not None:
    print("\n" + "="*80)
    print("SYSTEM-WIDE OPTIMIZATION SUMMARY")
    print("="*80)
    print(summary_df.to_string(index=False))
    
    # System totals
    total_passengers = summary_df['Monthly_Passengers'].sum()
    total_fleet = summary_df['Recommended_Fleet'].sum()
    total_cost = summary_df['Daily_Cost_IDR'].sum()
    total_fuel = summary_df['Daily_Fuel_L'].sum()
    
    print(f"\nSYSTEM TOTALS:")
    print(f"Total Monthly Passengers: {total_passengers:,.0f}")
    print(f"Total Recommended Fleet: {total_fleet:.0f} buses")
    print(f"Total Daily Operating Cost: IDR {total_cost/1000000:.1f} million")
    print(f"Total Daily Fuel Consumption: {total_fuel:,.0f} liters")
    print(f"Average Cost per Passenger: IDR {total_cost*30/total_passengers:.0f}")

# Print detailed analysis for each corridor
for corridor_name in koridor_data.keys():
    corridor_num = int(corridor_name.replace('Koridor', ''))
    optimizer.print_corridor_analysis(corridor_num)
# Out:
# Analyzing all loaded corridors...
#
# ================================================================================
# SYSTEM-WIDE OPTIMIZATION SUMMARY
# ================================================================================
#  Corridor  Length_km  Active_Stops  Monthly_Passengers  Peak_Hour_Demand  Recommended_Fleet  Recommended_Headway  Daily_Cost_IDR  Utilization_pct  Daily_Fuel_L
#         1      12.90            23        1.738658e+06       8693.289167               18.0             7.000000    2.665810e+07      1158.443255   1061.485714
#         2      14.00            22        9.351685e+05       4675.842500               18.0             7.000000    2.727360e+07       623.089615   1152.000000
#         3      19.00            13        8.808870e+05       4404.435000               20.4             7.000000    3.408082e+07       586.922616   1771.885714
#         4      11.85            17        5.265954e+05       2632.977083               14.4             7.000000    2.085647e+07       350.863118    780.068571
#         5      13.50            17        8.629871e+05       4314.935417               16.8             7.000000    2.519424e+07       574.996153   1036.800000
#         6      13.30            18        8.707745e+05       4353.872500               16.8             7.000000    2.508979e+07       580.184799   1021.440000
#         7      12.80            14        7.832537e+05       3916.268333               15.6             7.000000    2.305520e+07       521.870899    912.822857
#         8      26.00            22        1.023752e+06       5118.761667               27.6             7.000000    5.211511e+07       682.111777   3280.457143
#         9      28.80            33        1.623412e+06       8117.060000               31.2             7.000000    6.162838e+07      1081.656577   4107.702857
#        10      19.40            18        6.884827e+05       3442.413333               21.6             7.000000    3.635416e+07       458.726315   1915.611429
#        11      11.40            15        2.567437e+05       1283.718333               14.4             7.000000    2.065503e+07       171.064693    750.445714
#        12      23.80            14        2.805394e+05       1402.697024               24.0             7.000000    4.367616e+07       186.919459   2611.200000
#        13       9.40            15        1.115862e+06       5579.312143               13.2             7.000000    1.811312e+07       743.483438    567.222857
#        14       9.70             5        4.619665e+04        230.983250                4.8            15.919336    6.631351e+06        70.000000    212.845714
#
# SYSTEM TOTALS:
# Total Monthly Passengers: 11,633,313
# Total Recommended Fleet: 257 buses
# Total Daily Operating Cost: IDR 421.4 million
# Total Daily Fuel Consumption: 21,182 liters
# Average Cost per Passenger: IDR 1087
#
# ==================== KORIDOR 1 ANALYSIS ====================
# Corridor Length: 12.9 km
# Active Stops: 23
# Monthly Passengers: 1,738,658
# Peak Hour Demand: 8,693 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     13     1654.9   IDR 19.5    M
# Optimal         3.0      41     496.5    IDR 60.4    M
# Balanced        7.0      18     1158.4   IDR 26.7    M
# Frequent        5.0      25     827.5    IDR 37.3    M
# Cost_Efficient  12.0     11     1985.9   IDR 16.0    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. GELORA BUNG KARNO: 193,198/month
#    2. BUNDARAN HI ASTRA: 183,935/month
#    3. BLOK M: 126,158/month
#    4. KARET: 125,628/month
#    5. BUNDARAN SENAYAN: 125,212/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between BUNDARAN SENAYAN - GELORA BUNG KARNO
#       Potential: 95,523 passengers/month
#    2. Between TELUK BETUNG - BUNDARAN HI ASTRA
#       Potential: 82,949 passengers/month
#    3. Between GELORA BUNG KARNO - POLDA METRO JAYA
#       Potential: 74,904 passengers/month
#
# ==================== KORIDOR 2 ANALYSIS ====================
# Corridor Length: 14.0 km
# Active Stops: 22
# Monthly Passengers: 935,169
# Peak Hour Demand: 4,676 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     13     890.1    IDR 20.0    M
# Optimal         3.0      41     267.0    IDR 61.8    M
# Balanced        7.0      18     623.1    IDR 27.3    M
# Frequent        5.0      25     445.1    IDR 38.2    M
# Cost_Efficient  12.0     11     1068.2   IDR 16.4    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. JUANDA: 178,532/month
#    2. PULO GADUNG: 159,499/month
#    3. BALAI KOTA: 92,978/month
#    4. CEMPAKA MAS: 61,212/month
#    5. SUMUR BATU: 45,460/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between JUANDA - PECENONGAN
#       Potential: 66,697 passengers/month
#    2. Between ISTIQLAL - JUANDA
#       Potential: 55,173 passengers/month
#    3. Between PULO GADUNG - BERMIS
#       Potential: 52,692 passengers/month
#
# ==================== KORIDOR 3 ANALYSIS ====================
# Corridor Length: 19.0 km
# Active Stops: 13
# Monthly Passengers: 880,887
# Peak Hour Demand: 4,404 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     14     838.5    IDR 24.1    M
# Optimal         3.0      47     251.5    IDR 78.2    M
# Balanced        7.0      20     586.9    IDR 34.1    M
# Frequent        5.0      28     419.2    IDR 46.1    M
# Cost_Efficient  12.0     12     1006.2   IDR 20.0    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. KALIDERES: 183,714/month
#    2. JELAMBAR: 117,958/month
#    3. ROXY: 84,685/month
#    4. RAWA BUAYA: 80,060/month
#    5. GROGOL: 59,187/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between KALIDERES - PESAKIH
#       Potential: 65,384 passengers/month
#    2. Between JELAMBAR - GROGOL
#       Potential: 53,143 passengers/month
#    3. Between DAMAI - JELAMBAR
#       Potential: 47,272 passengers/month
#
# ==================== KORIDOR 4 ANALYSIS ====================
# Corridor Length: 11.85 km
# Active Stops: 17
# Monthly Passengers: 526,595
# Peak Hour Demand: 2,633 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     11     501.2    IDR 15.6    M
# Optimal         3.0      34     150.4    IDR 48.7    M
# Balanced        7.0      14     350.9    IDR 20.9    M
# Frequent        5.0      20     250.6    IDR 29.5    M
# Cost_Efficient  12.0     8      601.5    IDR 12.2    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. MANGGARAI: 95,942/month
#    2. RAWAMANGUN: 68,223/month
#    3. GALUNGGUNG: 63,765/month
#    4. PEMUDA RW.MANGUN: 52,318/month
#    5. PASAR GENJING: 29,957/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between MANGGARAI - PASAR RUMPUT
#       Potential: 36,877 passengers/month
#    2. Between FLYOVER PRAMUKA - MANGGARAI
#       Potential: 36,474 passengers/month
#    3. Between KAYU JATI - RAWAMANGUN
#       Potential: 29,005 passengers/month
#
# ==================== KORIDOR 5 ANALYSIS ====================
# Corridor Length: 13.5 km
# Active Stops: 17
# Monthly Passengers: 862,987
# Peak Hour Demand: 4,315 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     12     821.4    IDR 18.0    M
# Optimal         3.0      37     246.4    IDR 55.8    M
# Balanced        7.0      17     575.0    IDR 25.2    M
# Frequent        5.0      23     410.7    IDR 34.2    M
# Cost_Efficient  12.0     10     985.7    IDR 14.4    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. ANCOL: 135,446/month
#    2. PASEBAN: 122,180/month
#    3. PAL PUTIH: 72,686/month
#    4. MATRAMAN BARU: 68,843/month
#    5. GUNUNG SAHARI: 65,366/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between SALEMBA - PASEBAN
#       Potential: 50,373 passengers/month
#    2. Between ANCOL - PADEMANGAN
#       Potential: 47,694 passengers/month
#    3. Between PASEBAN - MATRAMAN
#       Potential: 44,808 passengers/month
#
# ==================== KORIDOR 6 ANALYSIS ====================
# Corridor Length: 13.3 km
# Active Stops: 18
# Monthly Passengers: 870,774
# Peak Hour Demand: 4,354 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     12     828.8    IDR 17.9    M
# Optimal         3.0      37     248.7    IDR 55.6    M
# Balanced        7.0      17     580.2    IDR 25.1    M
# Frequent        5.0      23     414.4    IDR 34.1    M
# Cost_Efficient  12.0     10     994.6    IDR 14.3    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. RAGUNAN: 168,836/month
#    2. RASUNA SAID: 85,103/month
#    3. KUNINGAN: 76,824/month
#    4. MAMPANG PRAPATAN: 63,596/month
#    5. DUREN TIGA: 56,980/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between RAGUNAN - SIMPANG RAGUNAN
#       Potential: 61,418 passengers/month
#    2. Between KUNINGAN - RASUNA SAID
#       Potential: 48,578 passengers/month
#    3. Between RASUNA SAID - KARET KUNINGAN
#       Potential: 39,465 passengers/month
#
# ==================== KORIDOR 7 ANALYSIS ====================
# Corridor Length: 12.8 km
# Active Stops: 14
# Monthly Passengers: 783,254
# Peak Hour Demand: 3,916 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     11     745.5    IDR 16.0    M
# Optimal         3.0      35     223.7    IDR 51.4    M
# Balanced        7.0      16     521.9    IDR 23.1    M
# Frequent        5.0      22     372.8    IDR 31.9    M
# Cost_Efficient  12.0     10     894.6    IDR 14.2    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. CAWANG: 132,716/month
#    2. CAWANG SENTRAL: 123,248/month
#    3. CILILITAN: 105,256/month
#    4. KAMPUNG RAMBUTAN: 78,457/month
#    5. FLYOVER RAYA BOGOR: 77,164/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between CAWANG SENTRAL - CAWANG
#       Potential: 76,789 passengers/month
#    2. Between CAWANG CILILITAN - CAWANG SENTRAL
#       Potential: 54,459 passengers/month
#    3. Between CILILITAN - CAWANG CILILITAN
#       Potential: 49,062 passengers/month
#
# ==================== KORIDOR 8 ANALYSIS ====================
# Corridor Length: 26.0 km
# Active Stops: 22
# Monthly Passengers: 1,023,752
# Peak Hour Demand: 5,119 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     19     974.4    IDR 36.3    M
# Optimal         3.0      64     292.3    IDR 120.1   M
# Balanced        7.0      28     682.1    IDR 52.1    M
# Frequent        5.0      38     487.2    IDR 72.5    M
# Cost_Efficient  12.0     17     1169.3   IDR 31.7    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. TANJUNG DUREN ARAH
# P.RANTI: 171,712/month
#    2. LEBAK BULUS: 116,220/month
#    3. TANJUNG DUREN ARAH
# PLUIT: 96,468/month
#    4. KEBAYORAN: 73,937/month
#    5. KEBON JERUK: 58,503/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between TANJUNG DUREN ARAH
# P.RANTI - TANJUNG DUREN ARAH
# PLUIT
#       Potential: 80,454 passengers/month
#    2. Between GROGOL REFORMASI - TANJUNG DUREN ARAH
# P.RANTI
#       Potential: 63,572 passengers/month
#    3. Between LEBAK BULUS - PONDOK PINANG
#       Potential: 44,334 passengers/month
#
# ==================== KORIDOR 9 ANALYSIS ====================
# Corridor Length: 28.8 km
# Active Stops: 33
# Monthly Passengers: 1,623,412
# Peak Hour Demand: 8,117 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     23     1545.2   IDR 45.0    M
# Optimal         3.0      73     463.6    IDR 144.6   M
# Balanced        7.0      31     1081.7   IDR 61.6    M
# Frequent        5.0      44     772.6    IDR 87.7    M
# Cost_Efficient  12.0     19     1854.3   IDR 37.9    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. PINANG RANTI: 172,676/month
#    2. PERTAMBURAN: 142,751/month
#    3. CIKOKO ARAH P.RANTI: 120,860/month
#    4. PENJARINGAN: 98,490/month
#    5. CIKOKO ARAH PLUIT: 82,376/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between PINANG RANTI - MAKASAR
#       Potential: 72,854 passengers/month
#    2. Between CIKOKO ARAH P.RANTI - CIKOKO ARAH PLUIT
#       Potential: 60,971 passengers/month
#    3. Between PERTAMBURAN - KEMANGGISAN ARAH
# P.RANTI
#       Potential: 54,081 passengers/month
#
# ==================== KORIDOR 10 ANALYSIS ====================
# Corridor Length: 19.4 km
# Active Stops: 18
# Monthly Passengers: 688,483
# Peak Hour Demand: 3,442 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     16     655.3    IDR 26.3    M
# Optimal         3.0      49     196.6    IDR 82.8    M
# Balanced        7.0      22     458.7    IDR 36.4    M
# Frequent        5.0      30     327.7    IDR 50.5    M
# Cost_Efficient  12.0     13     786.4    IDR 22.2    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. SUNTER KELAPA GADING: 98,950/month
#    2. PLUMPANG: 93,387/month
#    3. PGC: 91,475/month
#    4. WALIKOTA JAKARTA UTARA ARAH
# CILILITAN: 57,136/month
#    5. KAYU PUTIH RAWASARI: 50,191/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between PLUMPANG - WALIKOTA JAKARTA UTARA ARAH
# CILILITAN
#       Potential: 45,157 passengers/month
#    2. Between KODAMAR - PLUMPANG
#       Potential: 38,172 passengers/month
#    3. Between TERMINAL TJ.PRIUK - PGC
#       Potential: 37,993 passengers/month
#
# ==================== KORIDOR 11 ANALYSIS ====================
# Corridor Length: 11.4 km
# Active Stops: 15
# Monthly Passengers: 256,744
# Peak Hour Demand: 1,284 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     10     244.4    IDR 13.8    M
# Optimal         4.1      24     100.0    IDR 34.4    M
# Balanced        7.0      14     171.1    IDR 20.7    M
# Frequent        5.0      19     122.2    IDR 27.5    M
# Cost_Efficient  12.0     8      293.3    IDR 12.0    M
#
# RECOMMENDED SCENARIO: Optimal
#    Fleet Size: 24 buses
#    Headway: 4 minutes
#    Utilization: 100.0%
#    Daily Cost: IDR 34.4 million
#    Daily Fuel: 1251 liters
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. WALIKOTA JAKARTA TIMUR: 36,262/month
#    2. FLYOVER JATINEGARA: 31,288/month
#    3. STASIUN JATINEGARA: 30,326/month
#    4. FLYOVER PONDOK KOPI: 30,197/month
#    5. SIMPANG BUARAN: 23,532/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between FLYOVER JATINEGARA - STASIUN JATINEGARA
#       Potential: 18,484 passengers/month
#    2. Between PULO GEBANG - WALIKOTA JAKARTA TIMUR
#       Potential: 17,593 passengers/month
#    3. Between FLYOVER PONDOK KOPI - SIMPANG BUARAN
#       Potential: 16,119 passengers/month
#
# ==================== KORIDOR 12 ANALYSIS ====================
# Corridor Length: 23.8 km
# Active Stops: 14
# Monthly Passengers: 280,539
# Peak Hour Demand: 1,403 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     17     267.0    IDR 30.6    M
# Optimal         3.7      44     100.0    IDR 80.8    M
# Balanced        7.0      24     186.9    IDR 43.7    M
# Frequent        5.0      34     133.5    IDR 61.1    M
# Cost_Efficient  12.0     14     320.4    IDR 26.2    M
#
# RECOMMENDED SCENARIO: Optimal
#    Fleet Size: 44 buses
#    Headway: 4 minutes
#    Utilization: 100.0%
#    Daily Cost: IDR 80.8 million
#    Daily Fuel: 4831 liters
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. PLUIT SELATAN: 35,803/month
#    2. MANGGA DUA: 34,757/month
#    3. DANAU AGUNG: 30,008/month
#    4. PAKIN: 26,318/month
#    5. KALI BESAR: 25,329/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between PLUIT SELATAN - PAKIN
#       Potential: 18,636 passengers/month
#    2. Between BANDENGAN - KALI BESAR
#       Potential: 15,096 passengers/month
#    3. Between MANGGA DUA RAYA - MANGGA DUA
#       Potential: 13,877 passengers/month
#
# ==================== KORIDOR 13 ANALYSIS ====================
# Corridor Length: 9.4 km
# Active Stops: 15
# Monthly Passengers: 1,115,862
# Peak Hour Demand: 5,579 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     10     1062.1   IDR 13.2    M
# Optimal         3.0      29     318.6    IDR 39.5    M
# Balanced        7.0      13     743.5    IDR 18.1    M
# Frequent        5.0      18     531.1    IDR 24.7    M
# Cost_Efficient  12.0     7      1274.5   IDR 9.9     M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. PETUKANGAN JAKARTA: 201,978/month
#    2. PURI BETA 2: 184,134/month
#    3. CSW: 163,785/month
#    4. TEGAL MAMPANG: 110,579/month
#    5. VELBAK: 97,711/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between PETUKANGAN JAKARTA - PURI BETA 1
#       Potential: 84,398 passengers/month
#    2. Between PURI BETA 1 - PURI BETA 2
#       Potential: 79,045 passengers/month
#    3. Between PURI BETA 2 - CBD CILEDUK
#       Potential: 74,601 passengers/month
#
# ==================== KORIDOR 14 ANALYSIS ====================
# Corridor Length: 9.7 km
# Active Stops: 5
# Monthly Passengers: 46,197
# Peak Hour Demand: 231 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     8      44.0     IDR 11.6    M
# Optimal         22.7     4      100.0    IDR 5.0     M
# Balanced        15.9     5      70.0     IDR 6.6     M
# Frequent        5.0      16     22.0     IDR 21.6    M
# Cost_Efficient  12.0     7      52.8     IDR 9.9     M
#
# RECOMMENDED SCENARIO: Optimal
#    Fleet Size: 4 buses
#    Headway: 23 minutes
#    Utilization: 100.0%
#    Daily Cost: IDR 5.0 million
#    Daily Fuel: 160 liters
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. DANAU SUNTER: 15,474/month
#    2. JEMBATAN ITEM: 12,823/month
#    3. TANAH TINGGI: 7,237/month
#    4. KEMAYORAN: 6,560/month
#    5. PRJ: 4,102/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between DANAU SUNTER - JEMBATAN ITEM
#       Potential: 8,489 passengers/month
#    2. Between KEMAYORAN - DANAU SUNTER
#       Potential: 6,610 passengers/month
#    3. Between JEMBATAN ITEM - PRJ
#       Potential: 5,078 passengers/month

# %%
# ==================== EXPORT RESULTS ====================
def export_all_results():
    """Export all analysis results to CSV files"""
    export_files = []
    
    # System summary
    if summary_df is not None:
        summary_df.to_csv('transjakarta_system_optimization.csv', index=False)
        export_files.append('transjakarta_system_optimization.csv')
    
    # Individual corridor results
    for corridor_num, result in all_results.items():
        # Passenger data
        result['passenger_data'].to_csv(f'koridor{corridor_num}_passenger_data.csv', index=False)
        
        # Scenarios
        scenarios_df = pd.DataFrame([
            {'Scenario': k, **v} for k, v in result['scenarios'].items()
        ])
        scenarios_df.to_csv(f'koridor{corridor_num}_scenarios.csv', index=False)
        
        # Hotspots
        hotspots = optimizer.analyze_hotspots(corridor_num, 10)
        pd.DataFrame(hotspots).to_csv(f'koridor{corridor_num}_hotspots.csv', index=False)
        
        # New stops
        new_stops = optimizer.recommend_new_stops(corridor_num, 8)
        pd.DataFrame(new_stops).to_csv(f'koridor{corridor_num}_new_stops.csv', index=False)
        
        export_files.extend([
            f'koridor{corridor_num}_passenger_data.csv',
            f'koridor{corridor_num}_scenarios.csv',
            f'koridor{corridor_num}_hotspots.csv',
            f'koridor{corridor_num}_new_stops.csv'
        ])
    
    print(f"\nExported {len(export_files)} files:")
    for file in export_files:
        print(f"   - {file}")
    
    return export_files

# Export all results
exported_files = export_all_results()

print("\n" + "="*80)
print("ANALYSIS COMPLETE")
print("="*80)
print("All corridors have been optimized with comprehensive recommendations.")
print("Check the exported CSV files for detailed data and analysis results.")
# Out:
# Exported 57 files:
#    - transjakarta_system_optimization.csv
#    - koridor1_passenger_data.csv
#    - koridor1_scenarios.csv
#    - koridor1_hotspots.csv
#    - koridor1_new_stops.csv
#    - koridor2_passenger_data.csv
#    - koridor2_scenarios.csv
#    - koridor2_hotspots.csv
#    - koridor2_new_stops.csv
#    - koridor3_passenger_data.csv
#    - koridor3_scenarios.csv
#    - koridor3_hotspots.csv
#    - koridor3_new_stops.csv
#    - koridor4_passenger_data.csv
#    - koridor4_scenarios.csv
#    - koridor4_hotspots.csv
#    - koridor4_new_stops.csv
#    - koridor5_passenger_data.csv
#    - koridor5_scenarios.csv
#    - koridor5_hotspots.csv
#    - koridor5_new_stops.csv
#    - koridor6_passenger_data.csv
#    - koridor6_scenarios.csv
#    - koridor6_hotspots.csv
#    - koridor6_new_stops.csv
#    - koridor7_passenger_data.csv
#    - koridor7_scenarios.csv
#    - koridor7_hotspots.csv
#    - koridor7_new_stops.csv
#    - koridor8_passenger_data.csv
#    - koridor8_scenarios.csv
#    - koridor8_hotspots.csv
#    - koridor8_new_stops.csv
#    - koridor9_passenger_data.csv
#    - koridor9_scenarios.csv
#    - koridor9_hotspots.csv
#    - koridor9_new_stops.csv
#    - koridor10_passenger_data.csv
#    - koridor10_scenarios.csv
#    - koridor10_hotspots.csv
#    - koridor10_new_stops.csv
#    - koridor11_passenger_data.csv
#    - koridor11_scenarios.csv
#    - koridor11_hotspots.csv
#    - koridor11_new_stops.csv
#    - koridor12_passenger_data.csv
#    - koridor12_scenarios.csv
#    - koridor12_hotspots.csv
#    - koridor12_new_stops.csv
#    - koridor13_passenger_data.csv
#    - koridor13_scenarios.csv
#    - koridor13_hotspots.csv
#    - koridor13_new_stops.csv
#    - koridor14_passenger_data.csv
#    - koridor14_scenarios.csv
#    - koridor14_hotspots.csv
#    - koridor14_new_stops.csv
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================
# All corridors have been optimized with comprehensive recommendations.
# Check the exported CSV files for detailed data and analysis results.

# %%
# Analyze specific corridor
optimizer.print_corridor_analysis(1)  # Detailed analysis for Koridor 1

# Get hotspots for specific corridor
hotspots = optimizer.analyze_hotspots(1, top_n=10)

# Get new stop recommendations
new_stops = optimizer.recommend_new_stops(1, top_n=5)

# Access raw optimization results
result = optimizer.optimize_corridor(1)
print(result['scenarios']['Balanced'])  # Get balanced scenario data

# Access passenger data
df = optimizer.process_corridor_data('Koridor1')
print(df.head())  # View processed passenger data
# Out:
# ==================== KORIDOR 1 ANALYSIS ====================
# Corridor Length: 12.9 km
# Active Stops: 23
# Monthly Passengers: 1,738,658
# Peak Hour Demand: 8,693 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     13     1654.9   IDR 19.5    M
# Optimal         3.0      41     496.5    IDR 60.4    M
# Balanced        7.0      18     1158.4   IDR 26.7    M
# Frequent        5.0      25     827.5    IDR 37.3    M
# Cost_Efficient  12.0     11     1985.9   IDR 16.0    M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. GELORA BUNG KARNO: 193,198/month
#    2. BUNDARAN HI ASTRA: 183,935/month
#    3. BLOK M: 126,158/month
#    4. KARET: 125,628/month
#    5. BUNDARAN SENAYAN: 125,212/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between BUNDARAN SENAYAN - GELORA BUNG KARNO
#       Potential: 95,523 passengers/month
#    2. Between TELUK BETUNG - BUNDARAN HI ASTRA
#       Potential: 82,949 passengers/month
#    3. Between GELORA BUNG KARNO - POLDA METRO JAYA
#       Potential: 74,904 passengers/month
# {'headway': 7, 'fleet_size': np.float64(15.0), 'total_fleet': np.float64(18.0), 'utilization': np.float64(1158.4432546481378), 'daily_cost': np.float64(26658102.85714286), 'hourly_capacity': 750.4285714285713, 'fuel_liters': np.float64(1061.4857142857143)}
# 1                      JANUARI  FEBRUARI     MARET     APRIL       MEI  \
# 0             BLOK M  123540.0  110189.0  108999.0  110606.0  130527.0
# 1       MASJID AGUNG   42881.0   33257.0   38600.0   28312.0   40796.0
# 2   BUNDARAN SENAYAN   99055.0   88622.0   91420.0   81694.0  103004.0
# 3  GELORA BUNG KARNO  202051.0  185097.0  170657.0  158544.0  233412.0
# 4   POLDA METRO JAYA   57775.0   52460.0   48282.0   44377.0   61301.0
#
# 1      JUNI      JULI   AGUSTUS  SEPTEMBER   OKTOBER  NOVEMBER  DESEMBER  \
# 0  129018.0  138020.0  131816.0   129041.0  134175.0  128438.0  139525.0
# 1   36782.0   39727.0   35589.0    30556.0   38757.0   34578.0   33255.0
# 2  104924.0  130431.0  145639.0   157935.0  171705.0  164910.0  163207.0
# 3  228607.0  221730.0  200305.0   182811.0  177280.0  179140.0  178745.0
# 4   58520.0   61678.0   60359.0    60730.0   57523.0   55817.0   58956.0
#
# 1    Avg_Monthly  Peak_Month    Daily_Avg   Peak_Hour
# 0  126157.833333    139525.0  4205.261111  630.789167
# 1   36090.833333     42881.0  1203.027778  180.454167
# 2  125212.166667    171705.0  4173.738889  626.060833
# 3  193198.250000    233412.0  6439.941667  965.991250
# 4   56481.500000     61678.0  1882.716667  282.407500

# %%
# Analyze specific corridor
optimizer.print_corridor_analysis(13)  # Detailed analysis for Koridor 1

# Get hotspots for specific corridor
hotspots = optimizer.analyze_hotspots(13, top_n=10)

# Get new stop recommendations
new_stops = optimizer.recommend_new_stops(13, top_n=5)

# Access raw optimization results
result = optimizer.optimize_corridor(13)
print(result['scenarios']['Balanced'])  # Get balanced scenario data

# Access passenger data
df = optimizer.process_corridor_data('Koridor13')
print(df.head())  # View processed passenger data
# Out:
# ==================== KORIDOR 13 ANALYSIS ====================
# Corridor Length: 9.4 km
# Active Stops: 15
# Monthly Passengers: 1,115,862
# Peak Hour Demand: 5,579 passengers/hour
#
# SCENARIO COMPARISON:
# Scenario        Headway  Fleet  Util%    Daily Cost
# ------------------------------------------------------------
# Current         10.0     10     1062.1   IDR 13.2    M
# Optimal         3.0      29     318.6    IDR 39.5    M
# Balanced        7.0      13     743.5    IDR 18.1    M
# Frequent        5.0      18     531.1    IDR 24.7    M
# Cost_Efficient  12.0     7      1274.5   IDR 9.9     M
#
# TOP 5 PASSENGER HOTSPOTS:
#    1. PETUKANGAN JAKARTA: 201,978/month
#    2. PURI BETA 2: 184,134/month
#    3. CSW: 163,785/month
#    4. TEGAL MAMPANG: 110,579/month
#    5. VELBAK: 97,711/month
#
# TOP 3 NEW STOP RECOMMENDATIONS:
#    1. Between PETUKANGAN JAKARTA - PURI BETA 1
#       Potential: 84,398 passengers/month
#    2. Between PURI BETA 1 - PURI BETA 2
#       Potential: 79,045 passengers/month
#    3. Between PURI BETA 2 - CBD CILEDUK
#       Potential: 74,601 passengers/month
# {'headway': 7, 'fleet_size': np.float64(11.0), 'total_fleet': np.float64(13.2), 'utilization': np.float64(743.4834380354084), 'daily_cost': np.float64(18113115.42857143), 'hourly_capacity': 750.4285714285713, 'fuel_liters': np.float64(567.2228571428572)}
# 1                 JANUARI  FEBRUARI   MARET   APRIL     MEI    JUNI    JULI  \
# 0  TEGAL MAMPANG   128075    113594  122687  106917  109567  102825  117720
# 1     RAWA BARAT    28626     25490   25847   21261   26585   25758   32276
# 2    PASAR SANTA    40509     34090   32131   26343   33509   32769   45966
# 3            CSW   146561    133033  138781  126338  152728  160333  183765
# 4       MAYESTIK    36444     33837   34015   28000   35107   32908   40894
#
# 1   AGUSTUS  SEPTEMBER   OKTOBER  NOVEMBER  DESEMBER    Avg_Monthly  \
# 0  111927.0   101814.0  113680.0  101287.0   96856.0  110579.083333
# 1   34342.0    33663.0   39104.0   36789.0   35626.0   30447.250000
# 2   49553.0    45673.0   52282.0   49489.0   44231.0   40545.416667
# 3  183407.0   177270.0  201336.0  184794.0  177074.0  163785.000000
# 4   41513.0    38253.0   40627.0   39557.0   35562.0   36393.083333
#
# 1  Peak_Month    Daily_Avg   Peak_Hour
# 0    128075.0  3685.969444  552.895417
# 1     39104.0  1014.908333  152.236250
# 2     52282.0  1351.513889  202.727083
# 3    201336.0  5459.500000  818.925000
# 4     41513.0  1213.102778  181.965417
